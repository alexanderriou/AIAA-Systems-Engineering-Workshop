# %% [markdown]
# This code block demonstrates the following:
# - Reading a SysML 2.0 textual model and building a Python `Model` object
# - Generating outputs, both for serialization (i.e. portability) and model analysis
#     - `.JSON` supports model portability between programming languages and tools
#     - `.dot` supports graph theory based analysis
#     - `.csv` and `.xlsx` support analysis of the model in a tabular view
#     - `.txt` is a simple view of the model heirarchy
#     - `.png` is a graphical view generated by GraphViz

# %%
import os
from pysysml2.modeling import Model


in_dir = "./examples/models"
out_dir = "./examples/output"
in_sysml2 = [f for f in os.listdir(in_dir) if f.endswith(".sysml2")]

# Looping through all model files in the input directory
for in_f in in_sysml2:
    in_f = os.path.join(in_dir, in_f) # Set filename
    model = Model() # Create Model object
    model.from_sysml2_file(in_f) # Parse the textual model
    model.to_dot(out_dir) # Tranform model to a .dot file
    model.to_png(out_dir) # Export PNG of tree graph
    model.to_excel(out_dir) # Convert to tabular format
    model.to_csv(out_dir) # Export tabular view to CSV
    model.to_JSON(out_dir) # Serialize Model object to JSON
    model.to_txt(out_dir) # Output string representation
# Out:
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.2
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.2
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.2
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.2
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.2
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.2

# %%
import os
from pysysml2.modeling import Model


in_f = "./examples/updated_test/beagleplay_set1.sysml2"
# in_f = "./examples/models/model_test_1.sysml2"
model = Model() # Create Model object
model.from_sysml2_file(in_f) # Parse the textual model
# Out:
# line 148:20 extraneous input 'port' expecting {<EOF>, 'actor', 'attribute', 'comment', 'doc', 'import', 'item', 'package', 'part', 'ref', 'use', COMMENT_LONG}
# line 164:25 token recognition error at: ''openssh-'
# line 164:40 token recognition error at: '' :'
# line 173:25 token recognition error at: ''openssh-'
# line 173:40 token recognition error at: '' :'
# line 182:25 token recognition error at: ''libssl1.'
# line 182:35 token recognition error at: '' :'
# line 194:48 token recognition error at: ''openssh-'
# line 194:63 token recognition error at: ''.'
# line 195:28 token recognition error at: ''openssh-'
# line 195:43 token recognition error at: ''.'
# line 200:29 token recognition error at: '.'
# line 200:56 token recognition error at: '.'
# line 201:29 token recognition error at: '.'
# line 201:38 token recognition error at: ''BLE/'
# line 201:47 token recognition error at: '';'
# line 202:29 token recognition error at: '.'
# line 203:29 token recognition error at: '.'
# line 204:29 token recognition error at: '.'
# line 205:29 token recognition error at: '.'
# line 206:29 token recognition error at: '.'
# line 206:37 token recognition error at: ''USB-'
# line 206:43 token recognition error at: '';'
# line 207:29 token recognition error at: '.'
# line 207:37 token recognition error at: ''USB-'
# line 207:43 token recognition error at: '';'
# line 210:21 token recognition error at: ''USB-'
# line 210:27 token recognition error at: '-'
# line 210:34 token recognition error at: '' :'
# line 213:21 token recognition error at: ''USB-'
# line 213:27 token recognition error at: '-'
# line 213:34 token recognition error at: '' :'
# line 218:21 token recognition error at: ''USB-'
# line 218:27 token recognition error at: '-'
# line 218:34 token recognition error at: '' ='
# line 218:38 token recognition error at: ''USB-'
# line 218:44 token recognition error at: ''.'
# line 219:21 token recognition error at: ''USB-'
# line 219:27 token recognition error at: '-'
# line 219:34 token recognition error at: '' ='
# line 219:38 token recognition error at: ''USB-'
# line 219:44 token recognition error at: ''.'
# line 220:29 token recognition error at: '.'
# line 221:50 token recognition error at: '.'
# line 237:38 token recognition error at: '.'
# line 237:56 token recognition error at: '.'
# line 238:38 token recognition error at: '.'
# line 238:65 token recognition error at: '.'
# line 244:28 token recognition error at: '.'
# line 244:55 token recognition error at: '.'
# line 245:28 token recognition error at: '.'
# line 253:56 token recognition error at: '.'
# line 254:32 token recognition error at: '.'
# line 254:59 token recognition error at: '.'
# line 264:1 token recognition error at: '/\r'
# line 157:37 no viable alternative at input 'part'default image'defined'
# line 211:41 mismatched input 'USB_Type' expecting TYPE
# line 214:41 mismatched input 'USB_Type' expecting TYPE
# line 230:16 extraneous input '}' expecting {<EOF>, 'actor', 'attribute', 'comment', 'doc', 'import', 'item', 'package', 'part', 'ref', 'use', COMMENT_LONG}
